# %% [markdown]
# <a href="https://colab.research.google.com/github/natygaol/BOOTCAMP_DSG1/blob/semana05/01_primeros_pasos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Ejemplos básicos con Python**

# %%
import matplotlib.pyplot as plt

#datos
x = [1,2,3,4,5]
y = [1,4,9,16,25]

#creamos el grafico
plt.plot(x,y)
plt.title("grafico de ejemplo")
plt.xlabel("Eje X")
plt.ylabel("Eje Y")
plt.show()

# %%
categorias = ['A', 'B', 'C', 'D']
valores = [5, 7, 3, 8]

# crear el gráfico de barras
plt.bar(categorias, valores, color='green')
plt.title("Gráfico de Barras")
plt.xlabel("Categorías")
plt.ylabel("Valores")
plt.show()
